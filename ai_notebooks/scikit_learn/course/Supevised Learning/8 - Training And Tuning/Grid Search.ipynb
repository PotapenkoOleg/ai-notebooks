# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
import pandas as pd
import numpy as np

# 1. Define the model
model = SVC()

# 2. Create the parameter grid
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

data = pd.read_csv('./data/data.csv')

X_train = np.array(data[['x1', 'x2']])
y_train = np.array(data['y'])

from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score
scorer = make_scorer(f1_score)

# 3. Initialize and fit GridSearchCV
grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=5, scoring=scorer) # 'accuracy'
grid.fit(X_train, y_train)

# 4. Get the results
print(f"Best Estimator: {grid.best_estimator_}")
print(f"Best Parameters: {grid.best_params_}")
print(f"Best Score: {grid.best_score_}")
# Out:
# Best Estimator: SVC(C=10)
# Best Parameters: {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}
# Best Score: 0.9904761904761905
