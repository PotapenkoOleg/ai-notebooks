# %%
#  https://youtu.be/2uvysYbKdjM?si=DSY0FHQXRhD9dCV2

# %%
# !pip install pyarrow

# %%
import numpy as np
import pandas as pd

# %%
# pd.set_option("mode.dtype_backend", "pyarrow")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 pd.set_option("mode.dtype_backend", "pyarrow")
#
# File /opt/anaconda3/envs/numpy/lib/python3.12/site-packages/pandas/_config/config.py:274, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     273 def __call__(self, *args, **kwds) -> T:
# --> 274     return self.__func__(*args, **kwds)
#
# File /opt/anaconda3/envs/numpy/lib/python3.12/site-packages/pandas/_config/config.py:167, in _set_option(*args, **kwargs)
#     164     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     166 for k, v in zip(args[::2], args[1::2]):
# --> 167     key = _get_single_key(k, silent)
#     169     o = _get_registered_option(key)
#     170     if o and o.validator:
#
# ...

# %%
df = pd.read_csv('../data/fuel_econ.csv', engine='pyarrow')#, dtype_backend='pyarrow')

# %%
df.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3929 non-null   int64
#  1   make       3929 non-null   object
#  2   model      3929 non-null   object
#  3   year       3929 non-null   int64
#  4   VClass     3929 non-null   object
#  5   drive      3929 non-null   object
#  6   trans      3929 non-null   object
#  7   fuelType   3929 non-null   object
#  8   cylinders  3929 non-null   int64
#  9   displ      3929 non-null   float64
#  10  pv2        3929 non-null   int64
#  11  pv4        3929 non-null   int64
#  12  city       3929 non-null   float64
#  13  UCity      3929 non-null   float64
#  14  highway    3929 non-null   float64
#  15  UHighway   3929 non-null   float64
#  16  comb       3929 non-null   float64
#  17  co2        3929 non-null   int64
#  18  feScore    3929 non-null   int64
# ...

# %%
df.index = df['id']

# %%
df
# Out:
#           id        make             model  year           VClass  \
# id
# 32204  32204      Nissan              GT-R  2013  Subcompact Cars
# 32205  32205  Volkswagen                CC  2013     Compact Cars
# 32206  32206  Volkswagen                CC  2013     Compact Cars
# 32207  32207  Volkswagen        CC 4motion  2013     Compact Cars
# 32208  32208   Chevrolet    Malibu eAssist  2013     Midsize Cars
# ...      ...         ...               ...   ...              ...
# 39882  39882      Toyota       Prius Prime  2018     Midsize Cars
# 39898  39898     Hyundai     Sonata Hybrid  2018     Midsize Cars
# 39899  39899     Hyundai  Sonata Hybrid SE  2018     Midsize Cars
# 39900  39900       Lexus            LS 500  2018     Midsize Cars
# 39901  39901       Lexus        LS 500 AWD  2018     Midsize Cars
#
#                    drive                             trans          fuelType  \
# id
# 32204    All-Wheel Drive                   Automatic (AM6)  Premium Gasoline
# ...

# %%
df.at[32204, 'year']
# Out:
# 2013

# %%
for index, row in df.iterrows():
    pass

# %%
df[df['make'].str.contains('BMW|Lexus')]  # regex
# Out:
#           id   make            model  year        VClass              drive  \
# id
# 32209  32209  Lexus           GS 350  2013  Midsize Cars   Rear-Wheel Drive
# 32210  32210  Lexus       GS 350 AWD  2013  Midsize Cars    All-Wheel Drive
# 32339  32339  Lexus          GS 450h  2013  Midsize Cars   Rear-Wheel Drive
# 32593  32593    BMW  640i Gran Coupe  2013  Compact Cars   Rear-Wheel Drive
# 32710  32710  Lexus           ES 350  2013  Midsize Cars  Front-Wheel Drive
# ...      ...    ...              ...   ...           ...                ...
# 39865  39865    BMW     X2 xDrive28i  2018  Midsize Cars    All-Wheel Drive
# 39866  39866  Lexus          LS 500h  2018  Midsize Cars   Rear-Wheel Drive
# 39867  39867  Lexus      LS 500h AWD  2018  Midsize Cars    All-Wheel Drive
# 39900  39900  Lexus           LS 500  2018  Midsize Cars   Rear-Wheel Drive
# 39901  39901  Lexus       LS 500 AWD  2018  Midsize Cars    All-Wheel Drive
#
# ...

# %%
df.query('year == 2013 and make == "BMW"')
# Out:
#           id make             model  year           VClass             drive  \
# id
# 32593  32593  BMW   640i Gran Coupe  2013     Compact Cars  Rear-Wheel Drive
# 32885  32885  BMW              135i  2013  Subcompact Cars  Rear-Wheel Drive
# 32886  32886  BMW  135i Convertible  2013  Subcompact Cars  Rear-Wheel Drive
# 32887  32887  BMW  135i Convertible  2013  Subcompact Cars  Rear-Wheel Drive
# 32888  32888  BMW        335i Coupe  2013  Subcompact Cars  Rear-Wheel Drive
# ...      ...  ...               ...   ...              ...               ...
# 33296  33296  BMW   ActiveHybrid 7L  2013       Large Cars  Rear-Wheel Drive
# 33469  33469  BMW              320i  2013     Compact Cars  Rear-Wheel Drive
# 33470  33470  BMW       320i xDrive  2013     Compact Cars   All-Wheel Drive
# 33502  33502  BMW              320i  2013     Compact Cars  Rear-Wheel Drive
# 33759  33759  BMW       320i xDrive  2013     Compact Cars   All-Wheel Drive
#
# ...

# %%
df1 = df.copy()

# %%
# df['city'].interpolate()

# %%
pivot = df.pivot(columns='fuelType', index='id', values='city')

# %%
pivot
# Out:
# fuelType  Diesel  Midgrade Gasoline  Natural Gas  Premium Gasoline  \
# id
# 32204        NaN                NaN          NaN           16.4596
# 32205        NaN                NaN          NaN           21.8706
# 32206        NaN                NaN          NaN           17.4935
# 32207        NaN                NaN          NaN           16.9415
# 32208        NaN                NaN          NaN               NaN
# ...          ...                ...          ...               ...
# 39882        NaN                NaN          NaN               NaN
# 39898        NaN                NaN          NaN               NaN
# 39899        NaN                NaN          NaN               NaN
# 39900        NaN                NaN          NaN           19.2200
# 39901        NaN                NaN          NaN           18.0431
#
# fuelType  Regular Gasoline
# id
# 32204                  NaN
# 32205                  NaN
# 32206                  NaN
# 32207                  NaN
# ...

# %%
# shift() (LEAD/LAG)

# %%
# rank()

# %%
# df.rolling(3).mean()

# %%
# cumsum()
